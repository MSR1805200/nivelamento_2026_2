# %% [markdown]
# # Lista de Exercícios — Lógica de Programação com Python
#
# [![Abrir no Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MSR1805200/nivelamento_2026_2/blob/master/exercicios_aula_2_analise.ipynb).
#
# > **Orientação:** Em todas as questões, explique o seu raciocínio. Não basta apresentar apenas a resposta final.
#
# ---
#
# ## 1. Operações matemáticas
#
# Observe o código:
#
# ```python
# a = 10
# b = 3
#
# resultado = a + b * 2
#
# print(resultado)
# ```
#
# **Pergunta:** Qual será a saída do programa?
#
# Explique por que o resultado é esse.

# %% [markdown]
# ---
#
# ## 2. Operações matemáticas — encontre o erro
#
# Observe o código:
#
# ```python
# a = 20
# b = 5
#
# resultado = a / b
#
# print(Resultado)
# ```
#
# **Pergunta:** O código está correto?
#
# Se estiver errado:
#
# 1. explique qual é o erro;
# 2. escreva o código corrigido;
# 3. informe qual será a saída após a correção.
#
# ---

# %% [markdown]
# ## 3. Variáveis
#
# Observe:
#
# ```python
# numero = 10
#
# numero = numero + 5
# numero = numero * 2
#
# print(numero)
# ```
#
# **Pergunta:** Qual será a saída?
#
# Explique passo a passo o que acontece com a variável `numero`.

# %% [markdown]
# ---
#
# ## 4. Condicional simples
#
# Observe:
#
# ```python
# idade = 17
#
# if idade >= 18:
#     print("Maior de idade")
# else:
#     print("Menor de idade")
# ```
#
# **Pergunta:** Qual será a saída?
#
# Explique qual condição foi analisada pelo `if`.

# %% [markdown]
# ---
#
# ## 5. Condicional — encontre o erro
#
# Observe:
#
# ```python
# media = 8
#
# if media >= 7
#     print("Aprovado")
# else:
#     print("Reprovado")
# ```
#
# **Pergunta:**
#
# O código está correto?
#
# Caso esteja errado:
#
# 1. identifique o erro;
# 2. explique por que ele acontece;
# 3. escreva a versão correta.

# %% [markdown]
# ---
#
# ## 6. `if`, `elif` e `else`
#
# Observe:
#
# ```python
# media = 6
#
# if media >= 7:
#     print("Aprovado")
# elif media >= 5:
#     print("Recuperação")
# else:
#     print("Reprovado")
# ```
#
# **Pergunta:** Qual será a saída?
#
# Depois, responda:
#
# > Por que o programa não imprime `"Reprovado"`?

# %% [markdown]
# ---
#
# ## 7. Operador `%`
#
# Observe:
#
# ```python
# numero = 17
#
# if numero % 2 == 0:
#     print("Par")
# else:
#     print("Ímpar")
# ```
#
# **Pergunta:**
#
# 1. Qual será a saída?
# 2. O que significa o operador `%`?
# 3. Por que ele pode ser utilizado para descobrir se um número é par?

# %% [markdown]
# ---
#
# # `for`
#
# ## 8. Prevendo a execução de um `for`
#
# Observe:
#
# ```python
# for numero in range(1, 6):
#     print(numero)
# ```
#
# **Pergunta:** Qual será exatamente a saída?
#
# Explique por que o número `6` não aparece.
#
# ---

# %% [markdown]
# ## 9. `for` — encontre o erro
#
# Observe:
#
# ```python
# for numero in range(1, 6)
#     print(numero)
# ```
#
# **Pergunta:**
#
# 1. O código está correto?
# 2. Qual é o erro?
# 3. Como corrigir?
# 4. O que será impresso depois da correção?
#
# ---

# %% [markdown]
# ## 10. `for` com condição
#
# Observe:
#
# ```python
# for numero in range(1, 11):
#
#     if numero % 2 == 0:
#         print(numero)
# ```
#
# **Pergunta:** Qual será a saída?
#
# Explique por que alguns números não são impressos.
#
# ---

# %% [markdown]
# ## 11. `for` com acumulador
#
# Observe:
#
# ```python
# soma = 0
#
# for numero in range(1, 5):
#     soma = soma + numero
#
# print(soma)
# ```
#
# **Pergunta:**
#
# Qual será a saída?
#
# Mostre o valor de `soma` depois de cada repetição.

# %% [markdown]
# ---
#
# # `while`
#
# ## 12. Analisando um `while`
#
# Observe:
#
# ```python
# numero = 1
#
# while numero <= 5:
#     print(numero)
#     numero += 1
# ```
#
# **Pergunta:**
#
# 1. Qual será a saída?
# 2. Quantas vezes o `while` será executado?
# 3. Por que o programa termina?

# %% [markdown]
# ---
#
# ## 13. `while` — encontre o erro
#
# Observe:
#
# ```python
# numero = 1
#
# while numero <= 5:
#     print(numero)
# ```
#
# **Pergunta:**
#
# O código possui algum problema?
#
# Explique o que acontecerá quando o programa for executado.
#
# Depois, corrija o código.

# %% [markdown]
# ---
#
# ## 14. Comparando `for` e `while`
#
# Observe os dois códigos:
#
# **Código A**
#
# ```python
# for numero in range(1, 6):
#     print(numero)
# ```
#
# **Código B**
#
# ```python
# numero = 1
#
# while numero <= 5:
#     print(numero)
#     numero += 1
# ```
#
# **Pergunta:**
#
# 1. Os dois códigos produzem a mesma saída?
# 2. Qual será a saída?
# 3. Qual é a principal diferença entre as estratégias utilizadas?

# %% [markdown]
# ---
#
# # Listas
#
# ## 15. Analisando uma lista
#
# Observe:
#
# ```python
# frutas = ["maçã", "banana", "laranja", "uva"]
#
# print(frutas[0])
# print(frutas[2])
# print(frutas[-1])
# ```
#
# **Pergunta:** Qual será a saída?
#
# Explique o que significam os índices `0`, `2` e `-1`.

# %% [markdown]
# ---
#
# ## 16. Lista — encontre o erro
#
# Observe:
#
# ```python
# notas = [7, 8, 9, 10]
#
# print(notas[4])
# ```
#
# **Pergunta:**
#
# 1. O código está correto?
# 2. O que acontecerá quando ele for executado?
# 3. Por que isso acontece?
# 4. Qual índice poderia ser utilizado para acessar a nota `10`?

# %% [markdown]
# ---
#
# # Dicionários
#
# ## 17. Acessando informações
#
# Observe:
#
# ```python
# aluno = {
#     "nome": "João",
#     "idade": 20,
#     "curso": "Estatística"
# }
#
# print(aluno["nome"])
# print(aluno["curso"])
# ```
#
# **Pergunta:** Qual será a saída?
#
# Explique a diferença entre acessar uma informação de um dicionário e acessar uma informação de uma lista.

# %% [markdown]
# ---
#
# ## 18. Dicionário — encontre o erro
#
# Observe:
#
# ```python
# produto = {
#     "nome": "Notebook",
#     "preco": 3500,
#     "estoque": 10
# }
#
# print(produto["valor"])
# ```
#
# **Pergunta:**
#
# 1. O código está correto?
# 2. O que acontecerá quando ele for executado?
# 3. Qual é o erro?
# 4. Como corrigir o código para mostrar o preço?

# %% [markdown]
# ---
#
# # Integração
#
# ## 19. Lista + `for` + condicional
#
# Observe:
#
# ```python
# numeros = [10, 15, 20, 7, 30]
#
# contador = 0
#
# for numero in numeros:
#
#     if numero > 10:
#         contador += 1
#
# print(contador)
# ```
#
# **Pergunta:**
#
# 1. Qual será a saída?
# 2. Quais números foram considerados pelo `if`?
# 3. Qual é a função da variável `contador`?
# 4. Mostre o valor de `contador` após cada número ser analisado.

# %% [markdown]
# ---
#
# ## 20. Analise e corrija o programa
#
# Observe o código:
#
# ```python
# produto = {
#     "nome": "Teclado",
#     "preco": 150,
#     "estoque": 8
# }
#
# if produto["estoque"] > 0:
#     print("Produto disponível")
#
# for i in range(1, 4)
#     print(produto["nome"])
# ```
#
# **Pergunta:**
#
# O programa possui um ou mais erros.
#
# 1. Identifique todos os erros.
# 2. Explique cada erro.
# 3. Corrija o código.
# 4. Informe exatamente qual será a saída do programa corrigido.
#
# ---
